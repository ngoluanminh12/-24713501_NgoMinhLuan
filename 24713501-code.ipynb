# %%
product =[{
    "id":1,
    "name": "iphone",
    "price":100,
    "description":"iphone best"
},{
    "id":2,
    "name": "androi",
    "price":200,
    "description":"androi best"
}
]

# %%
product
# Out:
# [{'id': 1, 'name': 'iphone', 'price': 100, 'description': 'iphone best'},
#  {'id': 2, 'name': 'androi', 'price': 200, 'description': 'androi best'}]

# %%
type(product)
# Out:
# list

# %%
def xuatdanhsach():
    print("danh sach san pham cua toi la: \n")
    print("---------------\n")
    for p in product:
        print(f"ma san pham: {p['id']}")
        print(f"ten san pham: {p['name']}")
        print(f"gia san pham: {p['price']}")
        print(f"mo ta san pham: {p['description']}")
        print("-----------\n")

# %%
product[-1]["id"]+1
# Out:
# 3

# %%
if product:
    id=product[-1]["id"]+1
else:
    id=1

# %%
id=product[-1]["id"]+1 if product else 1

# %%
def themsp():
    n=int(input("nhap so sp: "))
    for i in range(1, n+1):
        ten = input("nhap ten sp: ")
        gia= float(input("nhap gia: "))
        mota= input("nhap mo ta: ")
        sp={
            "id": id,
            "name": ten,
            "price": gia,
            "description":mota
        }
        product.append(sp)

# %%
def xoatheoid():
    find_id= int(input("nhap id muon xoa: "))
    found = False
    for p in product:
        if p['id']==find_id:
            product.remove(p)
            print("da xoa thanh cong")
            found= True
            break
    if not found:
            print("khong tim thay id")
# Out:
# da xoa thanh cong

# %%
def timsp():
    timid= int(input("nhap id"))
    found=False
    for p in product:
        if p['id'] == timid:
            print(p)  
            found=True 
            break
    if not found:
        print("khong tim thay id")
             
timsp()
# Out:
# {'id': 2, 'name': 'androi', 'price': 200, 'description': 'androi best'}

# %%
def capnhat():
    id= int(input("nhap id "))
    found = False
    for p in product:
        if p['id'] == id:
            name=input("nhap ten moi")
            price=float(input("nhap gia"))
            description=input("nhap mo ta")
            if name:
                p['name'] = name
            if price:
                p['price']= price
            if description:
                p['description'] = description
            print("cap nhat thanh cong")
            found=True
            break
    if not found:    
        print("khong tim thay id")
            
        
capnhat()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 22
#      18     if not found:
#      19         print("khong tim thay id")
# ---> 22 capnhat()
#
# Cell In[108], line 7, in capnhat()
#       5 if p['id'] == id:
#       6     name=input("nhap ten moi")
# ----> 7     price=float(input("nhap gia"))
#       8     description=input("nhap mo ta")
#       9     if name:
#
# ValueError: could not convert string to float: ''

# %%
product
# Out:
# [{'id': 1, 'name': 'cho 36 meo', 'price': 36.0, 'description': 'meo'},
#  {'id': 2, 'name': 'meo', 'price': 36.0, 'description': 'cho'}]
